# %% [markdown]
# <a href="https://colab.research.google.com/github/imrannadaf250/code-python/blob/main/Untitled24.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a=10
b=20
c=30

if a>b:
  print("maximum is  a")
elif b>c:
  print("maximum is b")
else:
  print("maximum is c")
# Out:
# maximum is c

# %%
a = int(input("enter the value of a:"))

if a>0:
  print("Number is positive: ", a)
else:
  print("Number is negative:",a)
# Out:
# enter the value of a:-50
# Number is negative: -50

# %%
a = int(input("enter the value of a:"))

if a/5 and a/11:
  print("Number is divisible by 5 and 11")
else:
  print("Number is not divisible by 5 and 11")
# Out:
# enter the value of a:55
# Number is divisible by 5 and 11

# %%
a = int(input("enter the value of a:"))

if a%2 == 0:
  print("number is even")
else:
  print("number is odd")
# Out:
# enter the value of a:8
# number is even

# %%
a = int(input("enter a year:"))

if a%4 == 0:
  print(a," is a leap year")
else:
  print("not a leap year")
# Out:
# enter a year:2028
# 2028  is a leap year

# %%
char = input(("Enter a character:"))

if "a" <= char <= "z" or "A" <= char <= "Z":
  print(char, "is an alphabet")
else:
  print(char, "is not an alphabet")
# Out:
# Enter a character:A
# A is an alphabet

# %%
char = input(("Enter a alphabet:"))

if "a" in char or "e" in char or "i"  in char or "o"  in char or "u"  in char:
  print(char, "is a vowel")
else:
  print(char, "is not a vowel")
# Out:
# Enter a alphabet:u
# u is a vowel

# %%
char = input(("Enter a character:"))

if "A"<= char <= "Z":
  print("Uppercase")
elif "a"<= char <= "z":
  print("Lowercase")
else:
  print("Not character")
# Out:
# Enter a character:U
# Uppercase

# %%
char = input(("Enter a character:"))

if char.isupper():
  print("Uppercase")
elif char.islower():
  print("Lowercase")
else:
  print("Not character")
# Out:
# Enter a character:s
# Lowercase

# %%
2000//500
# Out:
# 4

# %%
a = int(input("Enter a triangle angle a:"))
b = int(input("Enter a triangle angle b:"))
c = int(input("Enter a triangle angle c:"))

#angle = a+b+c

if a+b+c != 180:
  print("Invalid triangle")
else:
  print("valid triangle")
# Out:
# Enter a triangle angle a:45
# Enter a triangle angle b:45
# Enter a triangle angle c:90
# valid triangle

# %%
a = int(input("Enter a triangle angle a:"))
b = int(input("Enter a triangle angle b:"))
c = int(input("Enter a triangle angle c:"))

if (a+b>c) and (b+c>a) and (c+a>b):
  print("Valid triangle")
else:
  print("Invalid triangle")
# Out:
# Enter a triangle angle a:8
# Enter a triangle angle b:7
# Enter a triangle angle c:9
# Valid triangle

# %%
a = int(input("Enter selling price:"))
b = int(input("Enter actual price:"))

if a > b:
  print("Profit")
else:
  print("Loss")
# Out:
# Enter selling price:500
# Enter actual price:450
# Profit

# %%
p= int(input("Enter a marks of physics:"))
c= int(input("Enter a marks of chemistry:"))
m= int(input("Enter a marks of maths:"))
b= int(input("Enter a marks of biology:"))
c= int(input("Enter a marks of computer:"))

total = p+c+m+b+c
per = total/5

print("Percentage:",per)

if per>=90:
  print("Grade A")
elif per>=80:
  print("Grade B")
elif per>=70:
  print("Grade C")
elif per>=60:
  print("Grade D")
elif per>=40:
  print("Grade E")
elif per<40:
  print("Grade F")
# Out:
# Enter a marks of physics:80
# Enter a marks of chemistry:70
# Enter a marks of maths:94
# Enter a marks of biology:85
# Enter a marks of computer:65
# Percentage: 77.8
# Grade C

# %%
sal = float(input("Enter a salary:"))

if sal<=10000:
  hra=sal*0.2
  da = sal*0.8
  print("hra:",hra,"da:",da,"Gross salary:",sal+hra+da)
elif sal<=20000:
  hra=sal*0.3
  da = sal*0.9
  print("hra:",hra,"da:",da,"Gross salary:",sal+hra+da)
elif sal>20000:
  hra=sal*0.35
  da = sal*0.95
  print("hra:",hra,"da:",da,"Gross salary:",sal+hra+da)
# Out:
# Enter a salary:15000
# hra: 4500.0 da: 13500.0 Gross salary: 33000.0
