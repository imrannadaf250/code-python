# %% [markdown]
# <a href="https://colab.research.google.com/github/imrannadaf250/code-python/blob/main/Copy_of_Untitled15.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
num = 10
while num > 5:
  print('hello',num)
  num -=1
# Out:
# hello 10
# hello 9
# hello 8
# hello 7
# hello 6

# %%
num = 1
total=0
while num<11:
  #print(num)
  total=total+num
  num +=1
print(total)
# Out:
# 55

# %%
#pin = input("Enter your pin:")

import getpass
pin = getpass.getpass("Enter your pin:")

while pin !='1234':
  print("Wrong pin")
  #pin = input("Enter your pin:")
  pin = getpass.getpass("Enter your pin:")
print("Correct pin")
# Out:
# Enter your pin:··········
# Correct pin

# %%
secret = 7
guess=0

while guess !=secret:
  guess = int(input("Guess the number:"))
  if guess !=secret:
    print("Wrong guess")
  else:
    print("Correct guess")
# Out:
# Guess the number:2
# Wrong guess
# Guess the number:7
# Correct guess

# %%
f = ['mango','apple','cherry','apple','grapes','mango','banana']

for item in f:
  if item == 'grapes':
    break
  else:
    print(item)
# Out:
# mango
# apple
# cherry
# apple

# %%
#break
products = ['mobile','laptop','headphone','mouse','keyboard','mobile','laptop','headphone']

search_item = input('Enter item to search:')

for item in products:
  print('Checking:',item)

  if item == search_item:
    print('Product found:',item)
    break
# Out:
# Enter item to search:laptop
# Checking: mobile
# Checking: laptop
# Product found: laptop

# %%
#continue
products = ['mobile','laptop','headphone','mouse','keyboard','mobile','laptop','headphone']

search_item = input('Enter item to search:')

for item in products:
 #print('Checking:',item)

  if item == search_item:
    print('Product found:',item)
    continue
# Out:
# Enter item to search:laptop
# Product found: laptop
# Product found: laptop

# %%
f=['apple','apple','cherry','grapes','mango','banana']
for item in f:
  if item !='grapes':
    continue
  else:
    print('Process:',item)
# Out:
# Process: grapes

# %%
candidate = [
    {'name':'gayatri','status':'present'},
    {'name':'ajay','status':'absent'},
    {'name':'gorakh','status':'present'},
    {'name':'tabassum','status':'absent'},
    {'name':'ajinkya','status':'present'},
    ]
  # give an assignment to the present candidates and skip absent candidates

for student in candidate:
  if student['status'] == 'present':
    print(student['name'], 'is present')
    continue
  else:
    print('Give an assignment to:',student['name'])
# Out:
# gayatri is present
# Give an assignment to: ajay
# gorakh is present
# Give an assignment to: tabassum
# ajinkya is present

# %%
#pass
if 2>1:
  pass

# %%
marks = [85,0,90,76,0,70,68,-1,88,96]

for mark in marks:

  if mark == -1:
    print('Invalid marks found, Stop checking',)
    continue

  if mark == 0:
    print('Absent Student, Skip this student')
    continue

  if mark < 40:
    pass

  print('Valid marks:',mark)
# Out:
# Valid marks: 85
# Absent Student, Skip this student
# Valid marks: 90
# Valid marks: 76
# Absent Student, Skip this student
# Valid marks: 70
# Valid marks: 68
# Invalid marks found, Stop checking
# Valid marks: 88
# Valid marks: 96

# %%
d = [2,3,4,5,6]
[ i**2 for i in d]
# Out:
# [4, 9, 16, 25, 36]

# %%
nms = ['prasad','imran','gayatri','jay','bhavana']
[nm.title() for nm in nms]
# Out:
# ['Prasad', 'Imran', 'Gayatri', 'Jay', 'Bhavana']

# %%
[ (nm.title(),len(nm)) for nm in nms]
# Out:
# [('Prasad', 6), ('Imran', 5), ('Gayatri', 7), ('Jay', 3), ('Bhavana', 7)]

# %%
[ nm.title() for nm in nms if len(nm)>6]
# Out:
# ['Gayatri', 'Bhavana']
