# %% [markdown]
# <a href="https://colab.research.google.com/github/imrannadaf250/code-python/blob/main/Untitled21.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
sq = lambda num: num**2

sq(9)
# Out:
# 81

# %%
test = lambda num: '+ve' if num>0 else '-ve'

test(90)
# Out:
# '+ve'

# %%
k = [20,5,4,60,10]

# apply an operation over each element from an iterable

map(lambda num: num*num,k)

# %%
tuple(map(lambda num: num*num,k))
# Out:
# (400, 25, 16, 3600, 100)

# %%
out = map(lambda num: num*num,k)
for val in out:
  if val>50:
    print(val)
# Out:
# 400
# 3600
# 100

# %%
names = ('gayatri', 'abdul','snehal','jay')

list(map(lambda names :names.upper(), names))
# Out:
# ['GAYATRI', 'ABDUL', 'SNEHAL', 'JAY']

# %%
list(map(lambda name : str.upper(name), names))
# Out:
# ['GAYATRI', 'ABDUL', 'SNEHAL', 'JAY']

# %%
p = (12,-33,40,-8,99,-12)


list (filter(lambda num : num<0,p))
# Out:
# [-33, -8, -12]
